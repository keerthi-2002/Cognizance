# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/cognizance-amrita/AI-Tasks/main/Task-1/Q2-Dataset.csv")

# %%
df.head()
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]
df = pd.read_csv("https://raw.githubusercontent.com/cognizance-amrita/AI-Tasks/main/Task-1/Q2-Dataset.csv", na_values = missing_value_formats)
print(df['Alley'].head(100))
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#      ...
# 94    NaN
# 95    NaN
# 96    NaN
# 97    NaN
# 98    NaN
# Name: Alley, Length: 99, dtype: object

# %%
print(df['LotFrontage'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95     True
# 96    False
# 97    False
# 98    False
# Name: LotFrontage, Length: 99, dtype: bool

# %%
print(df.isnull().sum())
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage     14
# LotArea          0
# Street           0
# Alley           93
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         3
# BsmtCond         3
# BsmtExposure     3
# BsmtFinType1     3
# BsmtFinSF1       0
# BsmtFinType2     3
# dtype: int64

# %%
df['LotFrontage'].fillna(1, inplace=True)
print(df['LotFrontage'])
# Out:
# 0     65.0
# 1     80.0
# 2     68.0
# 3     60.0
# 4     84.0
#       ...
# 94    69.0
# 95     1.0
# 96    78.0
# 97    73.0
# 98    85.0
# Name: LotFrontage, Length: 99, dtype: float64

# %%
print(df['Alley'].isnull())
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# Name: Alley, Length: 99, dtype: bool

# %%
df['Alley'].fillna('no alley mentioned', inplace=True)
print(df['Alley'])
# Out:
# 0     no alley mentioned
# 1     no alley mentioned
# 2     no alley mentioned
# 3     no alley mentioned
# 4     no alley mentioned
#              ...
# 94    no alley mentioned
# 95    no alley mentioned
# 96    no alley mentioned
# 97    no alley mentioned
# 98    no alley mentioned
# Name: Alley, Length: 99, dtype: object

# %%
print(df['BsmtQual'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtQual, Length: 99, dtype: bool

# %%
df[df['BsmtQual'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 17  18          90       RL         72.0    10791   Pave  no alley mentioned
# 39  40          90       RL         65.0     6040   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 17      Reg         Lvl    AllPub  ...          0        TA        TA
# 39      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation BsmtQual BsmtCond BsmtExposure  BsmtFinType1  BsmtFinSF1  \
# 17       Slab      NaN      NaN          NaN           NaN           0
# 39      PConc      NaN      NaN          NaN           NaN           0
# 90       Slab      NaN      NaN          NaN           NaN           0
#
#     BsmtFinType2
# 17           NaN
# 39           NaN
# 90           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtQual'].fillna('value is not given', inplace=True)

# %%
df.tail(10)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 89  90          20       RL         60.0     8070   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
# 91  92          20       RL         85.0     8500   Pave  no alley mentioned
# 92  93          30       RL         80.0    13360   Pave                Grvl
# 93  94         190  C (all)         60.0     7200   Pave  no alley mentioned
# 94  95          60       RL         69.0     9337   Pave  no alley mentioned
# 95  96          60       RL          NaN     9765   Pave  no alley mentioned
# 96  97          20       RL         78.0    10264   Pave  no alley mentioned
# 97  98          20       RL         73.0    10921   Pave  no alley mentioned
# 98  99          30       RL         85.0    10625   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 89      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
# 91      Reg         Lvl    AllPub  ...        203        TA        TA
# 92      IR1         HLS    AllPub  ...          0        TA        Gd
# 93      Reg         Lvl    AllPub  ...          0        TA        TA
# 94      IR1         Lvl    AllPub  ...          0        TA        Gd
# 95      IR2         Lvl    AllPub  ...         68        Ex        Gd
# 96      IR1         Lvl    AllPub  ...        183        Gd        TA
# 97      Reg         HLS    AllPub  ...         48        TA        TA
# 98      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond BsmtExposure  BsmtFinType1  \
# 89      PConc                  Gd       TA           No           GLQ
# 90       Slab  value is not given      NaN          NaN           NaN
# 91     CBlock                  TA       TA           No           Rec
# 92     BrkTil                  Gd       TA           No           ALQ
# 93     BrkTil                  TA       Fa           Mn           Rec
# 94      PConc                  Gd       TA           No           GLQ
# 95      PConc                  Gd       Gd           No           ALQ
# 96      PConc                  Gd       TA           Av           ALQ
# 97     CBlock                  TA       TA           No           Rec
# 98     BrkTil                  TA       TA           No           ALQ
#
#     BsmtFinSF1  BsmtFinType2
# 89         588           Unf
# 90           0           NaN
# 91         600           Unf
# 92         713           Unf
# 93        1046           Unf
# 94         648           Unf
# 95         310           Unf
# 96        1162           Unf
# 97         520           Unf
# 98         108           Unf
#
# [10 rows x 36 columns]

# %%
df[df['BsmtQual'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtCond'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtCond, Length: 99, dtype: bool

# %%
df[df['BsmtCond'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 17  18          90       RL         72.0    10791   Pave  no alley mentioned
# 39  40          90       RL         65.0     6040   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 17      Reg         Lvl    AllPub  ...          0        TA        TA
# 39      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond BsmtExposure  BsmtFinType1  \
# 17       Slab  value is not given      NaN          NaN           NaN
# 39      PConc  value is not given      NaN          NaN           NaN
# 90       Slab  value is not given      NaN          NaN           NaN
#
#     BsmtFinSF1  BsmtFinType2
# 17           0           NaN
# 39           0           NaN
# 90           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtCond'].fillna('Nothing', inplace=True)

# %%
df.tail(10)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 89  90          20       RL         60.0     8070   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
# 91  92          20       RL         85.0     8500   Pave  no alley mentioned
# 92  93          30       RL         80.0    13360   Pave                Grvl
# 93  94         190  C (all)         60.0     7200   Pave  no alley mentioned
# 94  95          60       RL         69.0     9337   Pave  no alley mentioned
# 95  96          60       RL          NaN     9765   Pave  no alley mentioned
# 96  97          20       RL         78.0    10264   Pave  no alley mentioned
# 97  98          20       RL         73.0    10921   Pave  no alley mentioned
# 98  99          30       RL         85.0    10625   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 89      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
# 91      Reg         Lvl    AllPub  ...        203        TA        TA
# 92      IR1         HLS    AllPub  ...          0        TA        Gd
# 93      Reg         Lvl    AllPub  ...          0        TA        TA
# 94      IR1         Lvl    AllPub  ...          0        TA        Gd
# 95      IR2         Lvl    AllPub  ...         68        Ex        Gd
# 96      IR1         Lvl    AllPub  ...        183        Gd        TA
# 97      Reg         HLS    AllPub  ...         48        TA        TA
# 98      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond BsmtExposure  BsmtFinType1  \
# 89      PConc                  Gd       TA           No           GLQ
# 90       Slab  value is not given  Nothing          NaN           NaN
# 91     CBlock                  TA       TA           No           Rec
# 92     BrkTil                  Gd       TA           No           ALQ
# 93     BrkTil                  TA       Fa           Mn           Rec
# 94      PConc                  Gd       TA           No           GLQ
# 95      PConc                  Gd       Gd           No           ALQ
# 96      PConc                  Gd       TA           Av           ALQ
# 97     CBlock                  TA       TA           No           Rec
# 98     BrkTil                  TA       TA           No           ALQ
#
#     BsmtFinSF1  BsmtFinType2
# 89         588           Unf
# 90           0           NaN
# 91         600           Unf
# 92         713           Unf
# 93        1046           Unf
# 94         648           Unf
# 95         310           Unf
# 96        1162           Unf
# 97         520           Unf
# 98         108           Unf
#
# [10 rows x 36 columns]

# %%
df[df['BsmtCond'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtExposure'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtExposure, Length: 99, dtype: bool

# %%
df[df['BsmtExposure'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 17  18          90       RL         72.0    10791   Pave  no alley mentioned
# 39  40          90       RL         65.0     6040   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 17      Reg         Lvl    AllPub  ...          0        TA        TA
# 39      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond BsmtExposure  BsmtFinType1  \
# 17       Slab  value is not given  Nothing          NaN           NaN
# 39      PConc  value is not given  Nothing          NaN           NaN
# 90       Slab  value is not given  Nothing          NaN           NaN
#
#     BsmtFinSF1  BsmtFinType2
# 17           0           NaN
# 39           0           NaN
# 90           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtExposure'].fillna('No exposure mentioned', inplace=True)

# %%
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 0    1          60       RL         65.0     8450   Pave  no alley mentioned
# 1    2          20       RL         80.0     9600   Pave  no alley mentioned
# 2    3          60       RL         68.0    11250   Pave  no alley mentioned
# 3    4          70       RL         60.0     9550   Pave  no alley mentioned
# 4    5          60       RL         84.0    14260   Pave  no alley mentioned
# 5    6          50       RL         85.0    14115   Pave  no alley mentioned
# 6    7          20       RL         75.0    10084   Pave  no alley mentioned
# 7    8          60       RL          NaN    10382   Pave  no alley mentioned
# 8    9          50       RM         51.0     6120   Pave  no alley mentioned
# 9   10         190       RL         50.0     7420   Pave  no alley mentioned
# 10  11          20       RL         70.0    11200   Pave  no alley mentioned
# 11  12          60       RL         85.0    11924   Pave  no alley mentioned
# 12  13          20       RL          NaN    12968   Pave  no alley mentioned
# 13  14          20       RL         91.0    10652   Pave  no alley mentioned
# 14  15          20       RL          NaN    10920   Pave  no alley mentioned
# 15  16          45       RM         51.0     6120   Pave  no alley mentioned
# 16  17          20       RL          NaN    11241   Pave  no alley mentioned
# 17  18          90       RL         72.0    10791   Pave  no alley mentioned
# 18  19          20       RL         66.0    13695   Pave  no alley mentioned
# 19  20          20       RL         70.0     7560   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 0       Reg         Lvl    AllPub  ...        196        Gd        TA
# 1       Reg         Lvl    AllPub  ...          0        TA        TA
# 2       IR1         Lvl    AllPub  ...        162        Gd        TA
# 3       IR1         Lvl    AllPub  ...          0        TA        TA
# 4       IR1         Lvl    AllPub  ...        350        Gd        TA
# 5       IR1         Lvl    AllPub  ...          0        TA        TA
# 6       Reg         Lvl    AllPub  ...        186        Gd        TA
# 7       IR1         Lvl    AllPub  ...        240        TA        TA
# 8       Reg         Lvl    AllPub  ...          0        TA        TA
# 9       Reg         Lvl    AllPub  ...          0        TA        TA
# 10      Reg         Lvl    AllPub  ...          0        TA        TA
# 11      IR1         Lvl    AllPub  ...        286        Ex        TA
# 12      IR2         Lvl    AllPub  ...          0        TA        TA
# 13      IR1         Lvl    AllPub  ...        306        Gd        TA
# 14      IR1         Lvl    AllPub  ...        212        TA        TA
# 15      Reg         Lvl    AllPub  ...          0        TA        TA
# 16      IR1         Lvl    AllPub  ...        180        TA        TA
# 17      Reg         Lvl    AllPub  ...          0        TA        TA
# 18      Reg         Lvl    AllPub  ...          0        TA        TA
# 19      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond           BsmtExposure  \
# 0       PConc                  Gd       TA                     No
# 1      CBlock                  Gd       TA                     Gd
# 2       PConc                  Gd       TA                     Mn
# 3      BrkTil                  TA       Gd                     No
# 4       PConc                  Gd       TA                     Av
# 5        Wood                  Gd       TA                     No
# 6       PConc                  Ex       TA                     Av
# 7      CBlock                  Gd       TA                     Mn
# 8      BrkTil                  TA       TA                     No
# 9      BrkTil                  TA       TA                     No
# 10     CBlock                  TA       TA                     No
# 11      PConc                  Ex       TA                     No
# 12     CBlock                  TA       TA                     No
# 13      PConc                  Gd       TA                     Av
# 14     CBlock                  TA       TA                     No
# 15     BrkTil                  TA       TA                     No
# 16     CBlock                  TA       TA                     No
# 17       Slab  value is not given  Nothing  No exposure mentioned
# 18      PConc                  TA       TA                     No
# 19     CBlock                  TA       TA                     No
#
#     BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 0            GLQ         706           Unf
# 1            ALQ         978           Unf
# 2            GLQ         486           Unf
# 3            ALQ         216           Unf
# 4            GLQ         655           Unf
# 5            GLQ         732           Unf
# 6            GLQ        1369           Unf
# 7            ALQ         859           BLQ
# 8            Unf           0           Unf
# 9            GLQ         851           Unf
# 10           Rec         906           Unf
# 11           GLQ         998           Unf
# 12           ALQ         737           Unf
# 13           Unf           0           Unf
# 14           BLQ         733           Unf
# 15           Unf           0           Unf
# 16           ALQ         578           Unf
# 17           NaN           0           NaN
# 18           GLQ         646           Unf
# 19           LwQ         504           Unf
#
# [20 rows x 36 columns]

# %%
df[df['BsmtExposure'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtFinType1'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtFinType1, Length: 99, dtype: bool

# %%
df[df['BsmtFinType1'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 17  18          90       RL         72.0    10791   Pave
# 39  40          90       RL         65.0     6040   Pave
# 90  91          20       RL         60.0     7200   Pave
#
#                       Alley LotShape LandContour Utilities  ... MasVnrArea  \
# 17  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 39  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 90  no alley name mentioned      Reg         Lvl    AllPub  ...          0
#
#    ExterQual ExterCond Foundation             BsmtQual BsmtCond  \
# 17        TA        TA       Slab  no value given here     None
# 39        TA        TA      PConc  no value given here     None
# 90        TA        TA       Slab  no value given here     None
#
#          BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 17  No given exposure           NaN           0           NaN
# 39  No given exposure           NaN           0           NaN
# 90  No given exposure           NaN           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtFinType1'].fillna('type1 not mentioned', inplace=True)

# %%
df.tail(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 79  80          50       RM         60.0    10440   Pave                Grvl
# 80  81          60       RL        100.0    13000   Pave  no alley mentioned
# 81  82         120       RM         32.0     4500   Pave  no alley mentioned
# 82  83          20       RL         78.0    10206   Pave  no alley mentioned
# 83  84          20       RL         80.0     8892   Pave  no alley mentioned
# 84  85          80       RL          NaN     8530   Pave  no alley mentioned
# 85  86          60       RL        121.0    16059   Pave  no alley mentioned
# 86  87          60       RL        122.0    11911   Pave  no alley mentioned
# 87  88         160       FV         40.0     3951   Pave                Pave
# 88  89          50  C (all)        105.0     8470   Pave  no alley mentioned
# 89  90          20       RL         60.0     8070   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
# 91  92          20       RL         85.0     8500   Pave  no alley mentioned
# 92  93          30       RL         80.0    13360   Pave                Grvl
# 93  94         190  C (all)         60.0     7200   Pave  no alley mentioned
# 94  95          60       RL         69.0     9337   Pave  no alley mentioned
# 95  96          60       RL          NaN     9765   Pave  no alley mentioned
# 96  97          20       RL         78.0    10264   Pave  no alley mentioned
# 97  98          20       RL         73.0    10921   Pave  no alley mentioned
# 98  99          30       RL         85.0    10625   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 79      Reg         Lvl    AllPub  ...          0        TA        TA
# 80      Reg         Lvl    AllPub  ...        576        TA        Gd
# 81      Reg         Lvl    AllPub  ...        443        TA        Gd
# 82      Reg         Lvl    AllPub  ...        468        TA        TA
# 83      IR1         Lvl    AllPub  ...         66        TA        TA
# 84      IR1         Lvl    AllPub  ...         22        TA        TA
# 85      Reg         Lvl    AllPub  ...        284        Gd        TA
# 86      IR2         Lvl    AllPub  ...          0        Gd        TA
# 87      Reg         Lvl    AllPub  ...         76        Gd        TA
# 88      IR1         Lvl    AllPub  ...          0        Fa        Fa
# 89      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
# 91      Reg         Lvl    AllPub  ...        203        TA        TA
# 92      IR1         HLS    AllPub  ...          0        TA        Gd
# 93      Reg         Lvl    AllPub  ...          0        TA        TA
# 94      IR1         Lvl    AllPub  ...          0        TA        Gd
# 95      IR2         Lvl    AllPub  ...         68        Ex        Gd
# 96      IR1         Lvl    AllPub  ...        183        Gd        TA
# 97      Reg         HLS    AllPub  ...         48        TA        TA
# 98      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond           BsmtExposure  \
# 79      PConc                  TA       TA                     No
# 80     CBlock                  Gd       TA                     No
# 81      PConc                  Ex       Gd                     No
# 82      PConc                  Gd       TA                     No
# 83     CBlock                  TA       TA                     No
# 84      PConc                  Gd       TA                     No
# 85     CBlock                  Gd       TA                     No
# 86      PConc                  Gd       TA                     Av
# 87      PConc                  Gd       TA                     Av
# 88     CBlock                  TA       Fa                     No
# 89      PConc                  Gd       TA                     No
# 90       Slab  value is not given  Nothing  No exposure mentioned
# 91     CBlock                  TA       TA                     No
# 92     BrkTil                  Gd       TA                     No
# 93     BrkTil                  TA       Fa                     Mn
# 94      PConc                  Gd       TA                     No
# 95      PConc                  Gd       Gd                     No
# 96      PConc                  Gd       TA                     Av
# 97     CBlock                  TA       TA                     No
# 98     BrkTil                  TA       TA                     No
#
#      BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 79            Unf           0           Unf
# 80            Rec         448           Unf
# 81            GLQ        1201           Unf
# 82            GLQ          33           Unf
# 83            Unf           0           Unf
# 84            Unf           0           Unf
# 85            Unf           0           Unf
# 86            Unf           0           Unf
# 87            Unf           0           Unf
# 88            Unf           0           Unf
# 89            GLQ         588           Unf
# 90  not mentioned           0           NaN
# 91            Rec         600           Unf
# 92            ALQ         713           Unf
# 93            Rec        1046           Unf
# 94            GLQ         648           Unf
# 95            ALQ         310           Unf
# 96            ALQ        1162           Unf
# 97            Rec         520           Unf
# 98            ALQ         108           Unf
#
# [20 rows x 36 columns]

# %%
df[df['BsmtFinType1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtFinType2'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtFinType2, Length: 99, dtype: bool

# %%
df['BsmtFinType2'].fillna(' type2 not mentioned', inplace=True)

# %%
df.tail(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street               Alley  \
# 79  80          50       RM         60.0    10440   Pave                Grvl
# 80  81          60       RL        100.0    13000   Pave  no alley mentioned
# 81  82         120       RM         32.0     4500   Pave  no alley mentioned
# 82  83          20       RL         78.0    10206   Pave  no alley mentioned
# 83  84          20       RL         80.0     8892   Pave  no alley mentioned
# 84  85          80       RL          NaN     8530   Pave  no alley mentioned
# 85  86          60       RL        121.0    16059   Pave  no alley mentioned
# 86  87          60       RL        122.0    11911   Pave  no alley mentioned
# 87  88         160       FV         40.0     3951   Pave                Pave
# 88  89          50  C (all)        105.0     8470   Pave  no alley mentioned
# 89  90          20       RL         60.0     8070   Pave  no alley mentioned
# 90  91          20       RL         60.0     7200   Pave  no alley mentioned
# 91  92          20       RL         85.0     8500   Pave  no alley mentioned
# 92  93          30       RL         80.0    13360   Pave                Grvl
# 93  94         190  C (all)         60.0     7200   Pave  no alley mentioned
# 94  95          60       RL         69.0     9337   Pave  no alley mentioned
# 95  96          60       RL          NaN     9765   Pave  no alley mentioned
# 96  97          20       RL         78.0    10264   Pave  no alley mentioned
# 97  98          20       RL         73.0    10921   Pave  no alley mentioned
# 98  99          30       RL         85.0    10625   Pave  no alley mentioned
#
#    LotShape LandContour Utilities  ... MasVnrArea ExterQual ExterCond  \
# 79      Reg         Lvl    AllPub  ...          0        TA        TA
# 80      Reg         Lvl    AllPub  ...        576        TA        Gd
# 81      Reg         Lvl    AllPub  ...        443        TA        Gd
# 82      Reg         Lvl    AllPub  ...        468        TA        TA
# 83      IR1         Lvl    AllPub  ...         66        TA        TA
# 84      IR1         Lvl    AllPub  ...         22        TA        TA
# 85      Reg         Lvl    AllPub  ...        284        Gd        TA
# 86      IR2         Lvl    AllPub  ...          0        Gd        TA
# 87      Reg         Lvl    AllPub  ...         76        Gd        TA
# 88      IR1         Lvl    AllPub  ...          0        Fa        Fa
# 89      Reg         Lvl    AllPub  ...          0        TA        TA
# 90      Reg         Lvl    AllPub  ...          0        TA        TA
# 91      Reg         Lvl    AllPub  ...        203        TA        TA
# 92      IR1         HLS    AllPub  ...          0        TA        Gd
# 93      Reg         Lvl    AllPub  ...          0        TA        TA
# 94      IR1         Lvl    AllPub  ...          0        TA        Gd
# 95      IR2         Lvl    AllPub  ...         68        Ex        Gd
# 96      IR1         Lvl    AllPub  ...        183        Gd        TA
# 97      Reg         HLS    AllPub  ...         48        TA        TA
# 98      Reg         Lvl    AllPub  ...          0        TA        TA
#
#    Foundation            BsmtQual BsmtCond           BsmtExposure  \
# 79      PConc                  TA       TA                     No
# 80     CBlock                  Gd       TA                     No
# 81      PConc                  Ex       Gd                     No
# 82      PConc                  Gd       TA                     No
# 83     CBlock                  TA       TA                     No
# 84      PConc                  Gd       TA                     No
# 85     CBlock                  Gd       TA                     No
# 86      PConc                  Gd       TA                     Av
# 87      PConc                  Gd       TA                     Av
# 88     CBlock                  TA       Fa                     No
# 89      PConc                  Gd       TA                     No
# 90       Slab  value is not given  Nothing  No exposure mentioned
# 91     CBlock                  TA       TA                     No
# 92     BrkTil                  Gd       TA                     No
# 93     BrkTil                  TA       Fa                     Mn
# 94      PConc                  Gd       TA                     No
# 95      PConc                  Gd       Gd                     No
# 96      PConc                  Gd       TA                     Av
# 97     CBlock                  TA       TA                     No
# 98     BrkTil                  TA       TA                     No
#
#      BsmtFinType1  BsmtFinSF1      BsmtFinType2
# 79            Unf           0               Unf
# 80            Rec         448               Unf
# 81            GLQ        1201               Unf
# 82            GLQ          33               Unf
# 83            Unf           0               Unf
# 84            Unf           0               Unf
# 85            Unf           0               Unf
# 86            Unf           0               Unf
# 87            Unf           0               Unf
# 88            Unf           0               Unf
# 89            GLQ         588               Unf
# 90  not mentioned           0   type2 not found
# 91            Rec         600               Unf
# 92            ALQ         713               Unf
# 93            Rec        1046               Unf
# 94            GLQ         648               Unf
# 95            ALQ         310               Unf
# 96            ALQ        1162               Unf
# 97            Rec         520               Unf
# 98            ALQ         108               Unf
#
# [20 rows x 36 columns]

# %%
df[df['BsmtFinType2'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df.isnull().sum())
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# Alley           0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# RoofMatl        0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# MasVnrArea      0
# ExterQual       0
# ExterCond       0
# Foundation      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinSF1      0
# BsmtFinType2    0
# dtype: int64
